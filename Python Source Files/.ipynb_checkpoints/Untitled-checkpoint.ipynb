# %%
def disc(a,b,c):
    return (b ** 2) - (4 * a * c)

def get_inputs(prompt):
    while True:
        try:
            a = float(input(prompt))
            return a
        except ValueError:
            print("Invalid input.\n")
    
while True:
    print("Provided that the equation is in the form of ax² + bx + c = 0(Where a is not 0)\n")
    a = get_inputs("What is a?")
    b = get_inputs("What is b?")
    c = get_inputs("What is c?")

    d = disc(a,b,c)
    if d >= 0:
        r1 = (-b + (d ** 0.5)) / (2 * a)
        r2 = (-b - (d ** 0.5)) / (2 * a)
        print(f"The roots to the equation {a}x²+{b}x+{c} are\n{r1},. and{r2}")
        if r1 == r2:
            prin(f"Hence, the root is {r1} twice")
    else:
        r1 = f"{(-b/(2 * a))} + {((-d ** 0.5) / (2 * a))}i"
        r2 = f"{(-b/(2 * a))} - {((-d ** 0.5) / (2 * a))}i"
        print(f"the roots are {r1}, and {r2} since the roots are imaginary.")
# Out:
#   Cell In[2], line 26
#     r1 = (-b/(2 * a)) + ((-d ** 0.5) / (2 * a))i
#                                                ^
# SyntaxError: invalid syntax
